# %% [markdown]
# ### Import Data

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
raw_data1 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/News - 11_train_data.csv")
raw_data2 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/News - 12_train_data.csv")
raw_data001 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 001.csv")
raw_data002 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 002.csv")
raw_data003 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 003.csv")
raw_data004 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 004.csv")
raw_data006 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 006.csv")
raw_data007 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 007.csv")
raw_data009 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 009.csv")
raw_data010 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 010.csv")
raw_data011 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 011.csv")
raw_data012 = pd.read_csv("/content/drive/MyDrive/IM 專題 - ESG rating system/data/news - 012.csv")

merged_data = pd.concat([raw_data1, raw_data2, raw_data001, raw_data002, raw_data003, raw_data004, raw_data006, raw_data007, raw_data009, raw_data010, raw_data011, raw_data012], axis=0, ignore_index=True)
raw_data = merged_data
raw_data

# %% [markdown]
# #### Data Clear

# %%
# 在 for loop 中根據條件刪除行
# 刪除沒有 content 的 row
for index, row in raw_data.iterrows():
  if type(raw_data["Content"][index]) != str:
    raw_data = raw_data.drop(index)
raw_data = raw_data.reset_index(drop=True)

num_of_content = len(raw_data)

# 將每個段落都加上標題
# 同時將 note 複製
now = "now"
note = "note"
for index, row in raw_data.iterrows():
  if type(raw_data["Name"][index]) == str:
    now = raw_data["Name"][index]
    note = raw_data["Note"][index]
  if type(raw_data["Name"][index]) != str:
    raw_data["Name"][index] = now
    raw_data["Note"][index] = note

# 刪掉 note="無關公司","無關組織","無關產業"的
for index, row in raw_data.iterrows():
  if raw_data["Note"][index] == "無關公司" or raw_data["Note"][index] == "無關組織" or raw_data["Note"][index] == "無關產業":
    raw_data = raw_data.drop(index)
raw_data = raw_data.reset_index(drop=True)

# %%
# 刪除沒有 label 的 data
for index, row in raw_data.iterrows():
  if type(raw_data["Tag01"][index]) != str:
    raw_data = raw_data.drop(index)
raw_data = raw_data.reset_index(drop=True)

# %% [markdown]
# #### Data Label

# %% [markdown]
# **段落** <br>
# 正向 = 1 <br>
# 負向 = -1 <br>
# 無關 = 0 <br>
# <br>
# **文章** <br>
# sum > 0 -> 正向
# sum = 0 -> 無關
# sum < 0 -> 負向

# %%
num_of_content = len(raw_data)
# new columns
raw_data["E"] = [0] * num_of_content
raw_data["S"] = [0] * num_of_content
raw_data["G"] = [0] * num_of_content
raw_data["E - 空氣污染"] = [0] * num_of_content
raw_data["E - 能源管理"] = [0] * num_of_content
raw_data["E - 燃料管理"] = [0] * num_of_content
raw_data["E - 產品包裝"] = [0] * num_of_content
raw_data["E - 生物多樣性"] = [0] * num_of_content
raw_data["E - 溫室氣體排放"] = [0] * num_of_content
raw_data["E - 水及污染管理"] = [0] * num_of_content
raw_data["E - 廢棄物處理"] = [0] * num_of_content
raw_data["S - 人權"] = [0] * num_of_content
raw_data["S - 社區關係"] = [0] * num_of_content
raw_data["S - 客戶福利"] = [0] * num_of_content
raw_data["S - 勞工關係"] = [0] * num_of_content
raw_data["S - 薪酬與福利"] = [0] * num_of_content
raw_data["S - 多樣性與共榮"] = [0] * num_of_content
raw_data["S - 僱員健康安全"] = [0] * num_of_content
raw_data["G - 商業倫理"] = [0] * num_of_content
raw_data["G - 物料採購"] = [0] * num_of_content
raw_data["G - 競爭行為"] = [0] * num_of_content
raw_data["G - 激勵措施"] = [0] * num_of_content
raw_data["G - 供應鏈管理"] = [0] * num_of_content
raw_data["G - 系統化管理"] = [0] * num_of_content
raw_data["G - 意外及安全"] = [0] * num_of_content

Ekeywords = ["空氣污染", "能源管理", "燃料管理", "產品包裝", "生物多樣性", "溫室氣體排放", "水及污染管理", "廢棄物處理"]
Skeywords = ["人權", "社區關係", "客戶福利", "勞工關係", "薪酬與福利", "多樣性與共融", "多樣性與共榮", "僱員健康安全"]
Gkeywords = ["商業倫理", "物料採購", "競爭行為", "激勵措施", "供應鏈管理", "系統化管理", "意外及安全"]

for i, row in raw_data.iterrows():
  if type(raw_data["Tag01"][i]) == str:
    if any(keyword in raw_data["Tag01"][i] for keyword in Ekeywords): raw_data["E"][i] = 1
    if any(keyword in raw_data["Tag01"][i] for keyword in Skeywords): raw_data["S"][i] = 1
    if any(keyword in raw_data["Tag01"][i] for keyword in Gkeywords): raw_data["G"][i] = 1
    if "空氣污染" in raw_data["Tag01"][i]:
        raw_data["E - 空氣污染"][i] = 1
        if "0" in raw_data["Tag01"][i]: raw_data["E - 空氣污染"][i] = -1
    if "能源管理" in raw_data["Tag01"][i]:
        raw_data["E - 能源管理"][i] = 1
        if "0" in raw_data["Tag01"][i]: raw_data["E - 能源管理"][i] = -1
    if "燃料管理" in raw_data["Tag01"][i]:
      raw_data["E - 燃料管理"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["E - 燃料管理"][i] = -1
    if "產品包裝" in raw_data["Tag01"][i]:
      raw_data["E - 產品包裝"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["E - 產品包裝"][i] = -1
    if "生物多樣性" in raw_data["Tag01"][i]:
      raw_data["E - 生物多樣性"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["E - 生物多樣性"][i] = -1
    if "溫室氣體排放" in raw_data["Tag01"][i]:
      raw_data["E - 溫室氣體排放"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["E - 溫室氣體排放"][i] = -1
    if "水及污染管理" in raw_data["Tag01"][i]:
      raw_data["E - 水及污染管理"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["E - 水及污染管理"][i] = -1
    if "廢棄物處理" in raw_data["Tag01"][i]:
      raw_data["E - 廢棄物處理"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["E - 廢棄物處理"][i] = -1
    if "人權" in raw_data["Tag01"][i]:
      raw_data["S - 人權"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 人權"][i] = -1
    if "社區關係" in raw_data["Tag01"][i]:
      raw_data["S - 社區關係"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 社區關係"][i] = -1
    if "客戶福利" in raw_data["Tag01"][i]:
      raw_data["S - 客戶福利"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 客戶福利"][i] = -1
    if "勞工關係" in raw_data["Tag01"][i]:
      raw_data["S - 勞工關係"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 勞工關係"][i] = -1
    if "薪酬與福利" in raw_data["Tag01"][i]:
      raw_data["S - 薪酬與福利"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 薪酬與福利"][i] = -1
    if "多樣性與共融" in raw_data["Tag01"][i]:
      raw_data["S - 多樣性與共榮"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 多樣性與共榮"][i] = -1
    if "多樣性與共榮" in raw_data["Tag01"][i]:
      raw_data["S - 多樣性與共榮"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 多樣性與共榮"][i] = -1
    if "僱員健康安全" in raw_data["Tag01"][i]:
      raw_data["S - 僱員健康安全"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["S - 僱員健康安全"][i] = -1
    if "商業倫理" in raw_data["Tag01"][i]:
      raw_data["G - 商業倫理"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["G - 商業倫理"][i] = -1
    if "物料採購" in raw_data["Tag01"][i]:
      raw_data["G - 物料採購"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["G - 物料採購"][i] = -1
    if "競爭行為" in raw_data["Tag01"][i]:
      raw_data["G - 競爭行為"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["G - 競爭行為"][i] = -1
    if "激勵措施" in raw_data["Tag01"][i]:
      raw_data["G - 激勵措施"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["G - 激勵措施"][i] = -1
    if "供應鏈管理" in raw_data["Tag01"][i]:
      raw_data["G - 供應鏈管理"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["G - 供應鏈管理"][i] = -1
    if "系統化管理" in raw_data["Tag01"][i]:
      raw_data["G - 系統化管理"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["G - 系統化管理"][i] = -1
    if "意外及安全" in raw_data["Tag01"][i]:
      raw_data["G - 意外及安全"][i] = 1
      if "0" in raw_data["Tag01"][i]: raw_data["G - 意外及安全"][i] = -1
  if type(raw_data["Tag02"][i]) == str:
    if any(keyword in raw_data["Tag02"][i] for keyword in Ekeywords): raw_data["E"][i] = 1
    if any(keyword in raw_data["Tag02"][i] for keyword in Skeywords): raw_data["S"][i] = 1
    if any(keyword in raw_data["Tag02"][i] for keyword in Gkeywords): raw_data["G"][i] = 1
    if "空氣污染" in raw_data["Tag02"][i]:
        raw_data["E - 空氣污染"][i] = 1
        if "0" in raw_data["Tag02"][i]: raw_data["E - 空氣污染"][i] = -1
    if "能源管理" in raw_data["Tag02"][i]:
        raw_data["E - 能源管理"][i] = 1
        if "0" in raw_data["Tag02"][i]: raw_data["E - 能源管理"][i] = -1
    if "燃料管理" in raw_data["Tag02"][i]:
      raw_data["E - 燃料管理"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["E - 燃料管理"][i] = -1
    if "產品包裝" in raw_data["Tag02"][i]:
      raw_data["E - 產品包裝"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["E - 產品包裝"][i] = -1
    if "生物多樣性" in raw_data["Tag02"][i]:
      raw_data["E - 生物多樣性"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["E - 生物多樣性"][i] = -1
    if "溫室氣體排放" in raw_data["Tag02"][i]:
      raw_data["E - 溫室氣體排放"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["E - 溫室氣體排放"][i] = -1
    if "水及污染管理" in raw_data["Tag02"][i]:
      raw_data["E - 水及污染管理"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["E - 水及污染管理"][i] = -1
    if "廢棄物處理" in raw_data["Tag02"][i]:
      raw_data["E - 廢棄物處理"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["E - 廢棄物處理"][i] = -1
    if "人權" in raw_data["Tag02"][i]:
      raw_data["S - 人權"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 人權"][i] = -1
    if "社區關係" in raw_data["Tag02"][i]:
      raw_data["S - 社區關係"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 社區關係"][i] = -1
    if "客戶福利" in raw_data["Tag02"][i]:
      raw_data["S - 客戶福利"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 客戶福利"][i] = -1
    if "勞工關係" in raw_data["Tag02"][i]:
      raw_data["S - 勞工關係"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 勞工關係"][i] = -1
    if "薪酬與福利" in raw_data["Tag02"][i]:
      raw_data["S - 薪酬與福利"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 薪酬與福利"][i] = -1
    if "多樣性與共融" in raw_data["Tag02"][i]:
      raw_data["S - 多樣性與共榮"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 多樣性與共榮"][i] = -1
    if "多樣性與共榮" in raw_data["Tag02"][i]:
      raw_data["S - 多樣性與共榮"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 多樣性與共榮"][i] = -1
    if "僱員健康安全" in raw_data["Tag02"][i]:
      raw_data["S - 僱員健康安全"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["S - 僱員健康安全"][i] = -1
    if "商業倫理" in raw_data["Tag02"][i]:
      raw_data["G - 商業倫理"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["G - 商業倫理"][i] = -1
    if "物料採購" in raw_data["Tag02"][i]:
      raw_data["G - 物料採購"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["G - 物料採購"][i] = -1
    if "競爭行為" in raw_data["Tag02"][i]:
      raw_data["G - 競爭行為"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["G - 競爭行為"][i] = -1
    if "激勵措施" in raw_data["Tag02"][i]:
      raw_data["G - 激勵措施"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["G - 激勵措施"][i] = -1
    if "供應鏈管理" in raw_data["Tag02"][i]:
      raw_data["G - 供應鏈管理"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["G - 供應鏈管理"][i] = -1
    if "系統化管理" in raw_data["Tag02"][i]:
      raw_data["G - 系統化管理"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["G - 系統化管理"][i] = -1
    if "意外及安全" in raw_data["Tag02"][i]:
      raw_data["G - 意外及安全"][i] = 1
      if "0" in raw_data["Tag02"][i]: raw_data["G - 意外及安全"][i] = -1
  if type(raw_data["Tag03"][i]) == str:
    if any(keyword in raw_data["Tag03"][i] for keyword in Ekeywords): raw_data["E"][i] = 1
    if any(keyword in raw_data["Tag03"][i] for keyword in Skeywords): raw_data["S"][i] = 1
    if any(keyword in raw_data["Tag03"][i] for keyword in Gkeywords): raw_data["G"][i] = 1
    if "空氣污染" in raw_data["Tag03"][i]:
        raw_data["E - 空氣污染"][i] = 1
        if "0" in raw_data["Tag03"][i]: raw_data["E - 空氣污染"][i] = -1
    if "能源管理" in raw_data["Tag03"][i]:
        raw_data["E - 能源管理"][i] = 1
        if "0" in raw_data["Tag03"][i]: raw_data["E - 能源管理"][i] = -1
    if "燃料管理" in raw_data["Tag03"][i]:
      raw_data["E - 燃料管理"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["E - 燃料管理"][i] = -1
    if "產品包裝" in raw_data["Tag03"][i]:
      raw_data["E - 產品包裝"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["E - 產品包裝"][i] = -1
    if "生物多樣性" in raw_data["Tag03"][i]:
      raw_data["E - 生物多樣性"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["E - 生物多樣性"][i] = -1
    if "溫室氣體排放" in raw_data["Tag03"][i]:
      raw_data["E - 溫室氣體排放"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["E - 溫室氣體排放"][i] = -1
    if "水及污染管理" in raw_data["Tag03"][i]:
      raw_data["E - 水及污染管理"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["E - 水及污染管理"][i] = -1
    if "廢棄物處理" in raw_data["Tag03"][i]:
      raw_data["E - 廢棄物處理"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["E - 廢棄物處理"][i] = -1
    if "人權" in raw_data["Tag03"][i]:
      raw_data["S - 人權"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 人權"][i] = -1
    if "社區關係" in raw_data["Tag03"][i]:
      raw_data["S - 社區關係"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 社區關係"][i] = -1
    if "客戶福利" in raw_data["Tag03"][i]:
      raw_data["S - 客戶福利"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 客戶福利"][i] = -1
    if "勞工關係" in raw_data["Tag03"][i]:
      raw_data["S - 勞工關係"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 勞工關係"][i] = -1
    if "薪酬與福利" in raw_data["Tag03"][i]:
      raw_data["S - 薪酬與福利"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 薪酬與福利"][i] = -1
    if "多樣性與共融" in raw_data["Tag03"][i]:
      raw_data["S - 多樣性與共榮"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 多樣性與共榮"][i] = -1
    if "多樣性與共榮" in raw_data["Tag03"][i]:
      raw_data["S - 多樣性與共榮"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 多樣性與共榮"][i] = -1
    if "僱員健康安全" in raw_data["Tag03"][i]:
      raw_data["S - 僱員健康安全"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["S - 僱員健康安全"][i] = -1
    if "商業倫理" in raw_data["Tag03"][i]:
      raw_data["G - 商業倫理"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["G - 商業倫理"][i] = -1
    if "物料採購" in raw_data["Tag03"][i]:
      raw_data["G - 物料採購"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["G - 物料採購"][i] = -1
    if "競爭行為" in raw_data["Tag03"][i]:
      raw_data["G - 競爭行為"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["G - 競爭行為"][i] = -1
    if "激勵措施" in raw_data["Tag03"][i]:
      raw_data["G - 激勵措施"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["G - 激勵措施"][i] = -1
    if "供應鏈管理" in raw_data["Tag03"][i]:
      raw_data["G - 供應鏈管理"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["G - 供應鏈管理"][i] = -1
    if "系統化管理" in raw_data["Tag03"][i]:
      raw_data["G - 系統化管理"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["G - 系統化管理"][i] = -1
    if "意外及安全" in raw_data["Tag03"][i]:
      raw_data["G - 意外及安全"][i] = 1
      if "0" in raw_data["Tag03"][i]: raw_data["G - 意外及安全"][i] = -1

# %%
# others (橫向合併)

# E - 空氣污染
# E - 燃料管理
# E - 產品包裝
# E - 生物多樣性

# S - 人權
# S - 客戶福利
# S - 多樣性與共榮
# S - 僱員健康安全

# G - 物料採購
# G - 競爭行為
# G - 激勵措施
# G - 系統化管理
# G - 意外及安全

E_others = ["E - 空氣污染", "E - 燃料管理", "E - 產品包裝", "E - 生物多樣性"]
S_others = ["S - 人權", "S - 客戶福利", "S - 多樣性與共榮", "S - 僱員健康安全"]
G_others = ["G - 物料採購", "G - 競爭行為", "G - 激勵措施", "G - 系統化管理", "G - 意外及安全"]

raw_data["E - others"] = raw_data[E_others].sum(axis=1).apply(lambda x: np.clip(x, -1, 1))
raw_data["S - others"] = raw_data[S_others].sum(axis=1).apply(lambda x: np.clip(x, -1, 1))
raw_data["G - others"] = raw_data[G_others].sum(axis=1).apply(lambda x: np.clip(x, -1, 1))

score_E = ["E", "E - 能源管理", "E - 溫室氣體排放", "E - 水及污染管理", "E - 廢棄物處理", "E - others"]
score_S = ["S", "S - 社區關係", "S - 勞工關係", "S - 薪酬與福利", "S - others"]
score_G = ["G", "G - 商業倫理", "G - 供應鏈管理", "G - others"]

raw_data["E"] = raw_data[score_E].sum(axis=1).apply(lambda x: np.clip(x, -1, 1))
raw_data["S"] = raw_data[score_S].sum(axis=1).apply(lambda x: np.clip(x, -1, 1))
raw_data["G"] = raw_data[score_G].sum(axis=1).apply(lambda x: np.clip(x, -1, 1))

# %%
# raw_data

# %%
data_top = raw_data.columns
print(data_top)

# %% [markdown]
# ### Rating

# %% [markdown]
# 台積電供應鏈：
#
# 上游：'愛譜 (6531)', 'M31 (6643)',
#
# 中游：'光洋科 (1785)', '盟立 (2464)', '弘塑 (3131)', '京鼎 (3413)', '家登 (3680)', '三福化 (4755)',  '世界 (5347)', '環球晶 (6488)',
#
# 下游：'日月光投控 (3711)', '精測 (6510)',
#
# 補：
#
# 上游：創意 (3443), 巨有科技 (8227), *聯發科 (2334)*
#
# 中游：昇陽半導體 (8028)
#
# 下游：勝一 (1773), 世禾 (3551), 辛耘 (3583), 上品 (4770), 聖暉 (5536), 迅得 (6438), 信紘科 (6667), 翔名(8091),

# %%
# raw_data["all"] = raw_data.iloc[:, -25:].sum(axis=1)
# raw_data

# %%
company_main = ["台積電"]
company_upstream = ["愛譜", "M31", "創意", "巨有科技", "聯發科"]
company_midstream = ["光洋科", "盟立", "弘塑", "京鼎", "家登", "三福化", "世界", "環球晶", "昇陽半導體"]
company_downstream = ["日月光投控", "精測", "勝一", "世禾", "辛耘", "上品", "聖暉", "迅得", "信紘科", "翔名"]
company = company_main + company_upstream + company_midstream + company_downstream

"""
score_E = ["E", "E - 能源管理", "E - 溫室氣體排放", "E - 水及污染管理", "E - 廢棄物處理", "E - others"]
score_S = ["S", "S - 社區關係", "S - 勞工關係", "S - 薪酬與福利", "S - others"]
score_G = ["G", "G - 商業倫理", "G - 供應鏈管理", "G - others"]
"""
score_item = score_E + score_S + score_G


# 權重用細項
# 大類 thres = 小類 thres * 類別數
# 小類 thres = 10
# 小類的平均 \= 大類


base_line = 50
threshold_item = 10  # 很關鍵

weight_all = pd.DataFrame()
score = pd.DataFrame()  # store all companies' score
company_data_num = []  # 該公司新聞總篇數
for i in range(len(company)):  # 計算各間公司的分數
  company_data  = raw_data[raw_data["Company"] == company[i]]
  company_doc_data = company_data.groupby('Name').sum(numeric_only=True).reset_index()
  company_doc_data_clip = company_doc_data.drop(columns=["Name", "xx"], axis=1).applymap(lambda x: np.clip(x, -1, 1))
  company_data_num_i = len(company_data)
  company_data_num.append(company_data_num_i)

  #score.loc[i, "公司"] = company[i]
  #score.loc[i, "新聞總篇數"] = company_data_num[i]

  for j in range(len(score_item)): # 逐類算分 # 細項
    threshold_item_j = threshold_item
    if score_item[j] == "E":
      threshold_item_j = threshold_item * (len(score_E)-1)
    elif score_item[j] == "S":
      threshold_item_j = threshold_item * (len(score_S)-1)
    elif score_item[j] == "G":
      threshold_item_j = threshold_item * (len(score_G)-1)
    doc_num_item_j = (company_doc_data_clip[score_item[j]] != 0).sum()
    weight = base_line / max(doc_num_item_j, threshold_item_j)
    company_score_item_j = company_doc_data_clip[score_item[j]].sum() * weight + base_line
    score.loc[i, score_item[j]] = company_score_item_j
    weight_all.loc[i, score_item[j]] = doc_num_item_j

display(score)
print(score)
#print(weight_all)
score.to_csv("/content/score.csv")
